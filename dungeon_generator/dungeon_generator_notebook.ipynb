# %%
from dungeon_generator import Dungeon

# %%
dungeon = Dungeon({5: 3}, 10)
dungeon.play()
# Out:
# ------------------------------------------------------
# HTTPError            Traceback (most recent call last)
# <ipython-input-13-8a9c44430a84> in <module>
# ----> 1 dungeon = Dungeon({5: 3}, 10)
#       2 dungeon.play()
#
# ~/dungeon_generator/dungeon_generator/dungeon_generator.py in __init__(self, party, highest_passive_perception, m, n, p_wall, include_doors, doors_open, plot_size, visible_traps)
#     201         self.C = self._adjacency(self.A, self.B) # after encounter placement, update adjacency
#     202
# --> 203         print(self.player_exp_df_url)
#     204         print(self.monster_df_url)
#     205
#
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/rexboyce/dungeon_generator/main/dungeon_generator/dnd_player_exp.csv')
# Out:
#     Player Level  Easy  Medium  Hard  Deadly
# 0              1    25      50    75     100
# 1              2    50     100   150     200
# 2              3    75     150   225     400
# 3              4   125     250   375     500
# 4              5   250     500   750    1100
# 5              6   300     600   900    1400
# 6              7   350     750  1100    1700
# 7              8   450     900  1400    2100
# 8              9   550    1100  1600    2400
# 9             10   600    1200  1900    2800
# 10            11   800    1600  2400    3600
# 11            12  1000    2000  3000    4500
# 12            13  1100    2200  3400    5100
# 13            14  1250    2500  3800    5700
# 14            15  1400    2800  4300    6400
# 15            16  1600    3200  4800    7200
# 16            17  2000    3900  5900    8800
# 17            18  2100    4200  6300    9500
# 18            19  2400    4900  7300   10900
# 19            20  2800    5700  8500   12700
